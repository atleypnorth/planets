# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')

# %%
df = pd.read_csv('c:/dev/lse/planets.tab', delimiter='\t', skiprows=383)

# %%
df['pl_disc'].plot.hist()

# %%
df['years_ago'] = df['pl_disc'] - 2016

# %%
df['years_ago'].plot.hist()

# %% [markdown]
# df.plot.scatter(x='pl_orbper', y='pl_orbsmax')

# %%
df[df['years_ago'] > -5]['years_ago'].plot.hist()

# %%
df[df['pl_orbper'] < 100].plot.scatter(x='pl_orbper', y='pl_orbsmax')
